# %% [markdown]
# ## B3a - Machine Learning
# Author: George Gorospe, george.gorospe@nmaia.net\
# Last Update: July 17th, 2026
#
# About: In this notebook you'll train your own AI on the data you collected earlier.
