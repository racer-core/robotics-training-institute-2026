# %% [markdown]
# ## A1 - First Drive - Getting to Know your Robot
# Author: George Gorospe, george.gorospe@nmaia.net\
# Last Update: July 13th, 2026
#
# About: In this notebook you'll learn and use basic commands to move your robot. These commands are important for the next steps in our learning!

# %% [markdown]
# Python code is what we use to communicate and control the robot. It's pretty useful and generally easy to understand!

# %%
# I AM A PYTHON CELL, I can do special things!
# Select this cell (blue outine), then use the "Play" button above to execute the code in this cell
print("It's that easy!")

# %% [markdown]
# #### Using Python to Command Your Robot:
# Python programs for your robot are like normal python programs but they result in some motion with your robot.
# You can use python to instruct your robot to Turn Left, Turn Right, Move Forward, or Move Backward.
#
# However, you have to use specific commands to make your robot move!
# This is an important part of programming for robotics, learning what commands can be used to program your robot.

# %% [markdown]
# ### In our program we'll follow the following sequence, consider it as a template:
#  Step 1. Import libraries designed specifically for your robot.
#  Step 2. Create the 'rvr' object from the sphero library, we can use this objcect as our interface to the robot.
#  Step 3. Issue commands to the rover's motors to move, this can be done multiple times.

# %%
#### ------> RUN THIS CELL WITHOUT CHANGING IT'S CONTENTS <-----#####
# STEP 1. Import libraries designed specifically for the robot

# Import the Sphero RVR Tank Robot Software Development Kit 
from sphero_sdk import RawMotorModesEnum
from sphero_sdk import DriveFlagsBitmask
import time

# Import our shared robot connection helpers
from robot_utils import get_rvr, close_if_exists

# %%
#### ------> RUN THIS CELL WITHOUT CHANGING IT'S CONTENTS <-----#####
# STEP 2. Create the 'rvr' object using our shared robot_utils helper.

# get_rvr() connects to the robot and wakes it up. If you re-run this cell,
# or if a connection already exists, it safely reuses it instead of opening
# a second one.
rvr = get_rvr()

# %% [markdown]
# Notice that `get_rvr()` takes care of waking up the robot for you automatically. Without it, your robot would fall asleep and not respond to your commands.

# %%
#### ------> RUN THIS CELL WITHOUT CHANGING IT'S CONTENTS <-----#####
# STEP 3. Issue commands to the robot, this can be done multiple times. 

######## WILL CAUSE ROBOT MOTION: ENSURE ROBOT IS ON THE GROUND #########

# When you execute this cell, the robot will be commanded to move forward by the computer.
##### IMPORTANT: the RVR has a 2 second command timeout, that means that after 2 seconds the RVR will come to a stop if it has not received a new command. #####
rvr.raw_motors(
    left_mode=RawMotorModesEnum.forward.value,     # Set the left motor mode: "forward"
    left_duty_cycle=50,  # Valid duty cycle range is 0-255
    right_mode=RawMotorModesEnum.forward.value,    # Set the right motor mode: "forward
    right_duty_cycle=50  # Valid duty cycle range is 0-255
    )

# %% [markdown]
# ### IMPORTANT: the RVR has a 2 second command timeout, that means that after 2 seconds the RVR will come to a stop if it has not received a new command. So you should have seen your robot move then stop on its own.

# %% [markdown]
# ### About the Code Example: Commanding the Robot to Move Forward
#  We can command the robot to move forward by with a very specific funtion:
# ```rvr.raw_motors()```
#
# ```rvr.raw_motors()``` takes up to 4 inputs:
#  + ```left_mode```
#  + ```left_duty_cycle```
#  + ```right_mode```
#  + ```right_duty_cycle```
#
#
# Motor modes can be set to either:
#  + ```RawMotorModesEnum.forward.value```
#  + ```RawMotorModesEnum.reverse.value```
#
# **Example**: ```left_mode = RawMotorModesEnum.reverse.value```
# This would put the left motor in 'reverse' mode.
# **Note**: the capitalization and spelling matter here, so make sure you double check your work!
#
# The motor duty cycle is the **speed** for each motor
#  + must be set to a value between 0 and 255
#
# **Example**: ```right_duty_cycle=200```

# %% [markdown]
# <span style="color: green; font-size: 55px; font-style: italic;">Student Discusion Time</span>

# %% [markdown]
# ### **STUDENT QUESTIONS**:
#  + ### What if we later need to move forward ➡️, turn left ⤴️, then move forward ➡️ again?
#  + ### How can we make the code more accessible?
#
# ### **ANSWER**: **Functions** - think of them as little packages of code that make it easy to use the package over and over.
#
# ### **Activity A1.1**: Use the following cell to make a move_forward() function.
# I've setup the basic function form, its up to you to fill in the middle using our the code from our previous CODE EXAMPLE.

# %% [markdown]
# <span style="color: orange; font-size: 55px; font-style: italic;">ACTIVITY A1.1: move_forward function</span>

# %%
#### ------> ACTIVITY A1.1: move_forward function <-----#####
# About: Creating a custom function, "move_forward" for our robot

##### INSTRUCTIONS: #####
# 1. Quickly look at the function definition I've provided, it is incomplete.
# 2. Write in the command to move the robot forward under the "#<<<<<< replace this with your code >>>>>>"
# 3. Test your answer with the "play button". If it works your robot should move forward and you can move to the next cell.

# All custom fucntions start with "def" then the name of the function and two perentheses
def move_forward():
    # Print statement: tells us whats happening
    print("Waking up robot")
    rvr.wake()
    time.sleep(2) # Computer waits for 2 seconds as the robot wakes up
    
    print("robot moving forward")

    #<<<<<< replace this with your code >>>>>>
    # Make sure it is indented and aligned with this text.


    

# Execuate youre new custom function!
# This is called a function call
move_forward()

# %% [markdown]
# ### Did your robot move forward???
# ### **Thats great!!** 🎉🎉

# %% [markdown]
# ### Lets now create a function for moving **backward**.
#
# This will have the same structure as what we used before but there are two big changes:
#  + Set "**left_mode**" to "**RawMotorModesEnum.reverse.value**'
#  + Set "**right_mode**" to "**RawMotorModesEnum.reverse.value**'
#
# IMPORTANT: You must capitalize correctly as its seen in the example code.
# I started the function for you. You do the rest.

# %% [markdown]
# <span style="color: orange; font-size: 55px; font-style: italic;">ACTIVITY A1.2: move_backward function</span>

# %%
#### ------> ACTIVITY A1.2: move_backward function <-----#####
# Creating a custom function, "move_backward" for our robot

##### INSTRUCTIONS: #####
# 1. Quickly look at the function definition I've provided, it is incomplete.
# 2. Write in the command to move the robot forward under the "#<<<<<< replace this with your code >>>>>>"
# 3. Test your answer with the "play button". If it works your robot should move forward and you can move to the next cell.

# All custom fucntions start with "def" then the name of the function and two perentheses
def move_backward():
    # Print statement: tells us whats happening
    print("Waking up robot")
    rvr.wake()
    time.sleep(2) # Computer waits for 2 seconds as the robot wakes up
    
    print("robot moving backward")

    #<<<<<< replace this with your code >>>>>>

    

# Execuate the new custom function
move_backward()

# %% [markdown]
# ### Now that we've mastered moving our robot forwards and backwards we need to learn how to turn our robot.
# The pattern is the same, we create a custom function. Then in the function we wake up the robot and then use the ```rvr.raw_motors()``` command.
# **But this time,** we'll set one motor to move forwards and the other to move backwards using ```RawMotorModes.Enum```

# %% [markdown]
# <span style="color: orange; font-size: 55px; font-style: italic;">ACTIVITY A1.3: turn_right and turn_left functions</span>

# %% [markdown]
# ### Below are two turning functions labeled: turn_right and turn_left
# Your job is to complete the functions such that each makes the robot turn its respective direction.
# We want to use `turn left` and `turn_right` in our programs later.

# %%
#### ------> ACTIVITY A1.3: turn_right and turn_left functions <-----#####
# Complete the custom function, "turn_right" for our robot


##### INSTRUCTIONS: #####
# 1. Quickly look at the function definition I've provided, it is incomplete.
# 2. Write in the command to move the robot RIGHT under the "#<<<<<< replace this with your code >>>>>>"
# 3. Test your answer with the "play button". If it works your robot should move forward and you can move to the next cell.

# All custom fucntions start with "def" then the name of the function and two perentheses
def turn_right():
    # Print statement: tells us whats happening
    print("Waking up robot")
    rvr.wake()
    time.sleep(2) # Computer waits for 2 seconds as the robot wakes up
    
    print("robot turning left? right? Who knows?") # REMOVE THIS WHEN YOU"RE CONFIDENT THAT THE ROBOT IS TURNING CORRECTLY.

    #<<<<<< replace this with your code >>>>>>


# Execuate the new custom function
turn_right()

# %%
#### ------> ACTIVITY A1.3: turn_right and turn_left functions <-----#####
# Complete the custom function, "turn_left" for our robot

##### INSTRUCTIONS: #####
# 1. Quickly look at the function definition I've provided, it is incomplete.
# 2. Write in the command to move the robot LEFT under the "#<<<<<< replace this with your code >>>>>>"
# 3. Test your answer with the "play button". If it works your robot should move forward and you can move to the next cell.

# All custom fucntions start with "def" then the name of the function and two perentheses
def turn_left():
    # Print statement: tells us whats happening
    print("Waking up robot")
    rvr.wake()
    time.sleep(2) # Computer waits for 2 seconds as the robot wakes up
    
    print("robot turning left? right? Who knows?") # REMOVE THIS WHEN YOU"RE CONFIDENT THAT THE ROBOT IS TURNING CORRECTLY.

    #<<<<<< replace this with your code >>>>>>


# Execuate the new custom function
turn_left()

# %% [markdown]
# ### Hopefully, you've now got four commands for your robot:
#
# ### [```move_forward```, ```move_backward```, ```turn_left```, ```turn_right```]

# %% [markdown]
# <span style="color: orange; font-size: 55px; font-style: italic;">ACTIVITY A1.4: Complete the Square</span>

# %% [markdown]
# ## Student Challenge: command your robot to execute a square path

# %%
#### ------> ACTIVITY A1.4: Complete the Square <-----#####
# Use your custom functions to make your robot draw a square on the ground. Just like turtle!

##### INSTRUCTIONS: #####
# 1. Use the functions you've created to write a sequence of moves for your robot, this sequence should direct the robot draw a square.
# 2. Test, test, test. When you're successful get a staff member to see your robot do a square.

#<<<<<< write your code for a square below this >>>>>>

# %% [markdown]
# ## Bonus: if you finish early, try to make your robot do a figure 8.

# %% [markdown]
# # SOLUTIONS:

# %% [markdown]
# ### ------> SOLUTION - Activity A1.1: move_forward function <-----

# %%
#### ------> SOLUTION - Activity A1.1: move_forward function <-----#####
# Creating a custom function, "move_forward" for our robot

##### INSTRUCTIONS: #####
# 1. Read all the green text, they are comments or "clues" about the code
# 2. Write in the command to move the robot forward under the "#<<<<<< replace this with your code >>>>>>"
# 3. Run the cell with the "play button" to test your code. If it works, you can move to the next cell.

# All custom fucntions start with "def" then the name of the function and two perentheses
def move_forward():
    # Print statement: tells us whats happening
    print("Waking up robot")
    rvr.wake()
    time.sleep(2) # Computer waits for 2 seconds as the robot wakes up
    
    print("robot moving forward")
    
    # GEORGE's Solution:
    rvr.raw_motors(
        left_mode=RawMotorModesEnum.forward.value,     # Set the left motor mode: "forward"
        left_duty_cycle=50,  # Valid duty cycle range is 0-255
        right_mode=RawMotorModesEnum.forward.value,    # Set the right motor mode: "forward
        right_duty_cycle=50  # Valid duty cycle range is 0-255
        )


    

# Execuate youre new custom function!
# This is called a function call
move_forward()

# %% [markdown]
# #### ------> SOLUTION - Activity A1.2: move_backward function <-----#####

# %%
#### ------> SOLUTION - ACTIVITY A1.2: move_backward function <-----#####
# Creating a custom function, "move_backward" for our robot

##### INSTRUCTIONS: #####
# 1. Read all the green text, they are comments or "clues" about the code
# 2. Write in the command to move the robot forward under the "#<<<<<< replace this with your code >>>>>>"
# 3. Run the cell with the "play button" to test your code. If it works, you can move to the next cell.

# All custom fucntions start with "def" then the name of the function and two perentheses
def move_backward():
    # Print statement: tells us whats happening
    print("Waking up robot")
    rvr.wake()
    time.sleep(2) # Computer waits for 2 seconds as the robot wakes up
    
    print("robot moving backward")

    # GEORGE's Solution:
    rvr.raw_motors(
    left_mode=RawMotorModesEnum.reverse.value,
    left_duty_cycle=50,  # Valid duty cycle range is 0-255
    right_mode=RawMotorModesEnum.reverse.value,
    right_duty_cycle=50  # Valid duty cycle range is 0-255
    )


    

# Execuate the new custom function
move_backward()

# %% [markdown]
# #### ------> SOLUTION - Activity A1.3: turnt_right and turn_left functions <-----#####

# %%
#### ------> ACTIVITY A1.3: turn_right and turn_left functions <-----#####
# Complete the custom function, "turn_right" for our robot


##### INSTRUCTIONS: #####
# 1. Quickly look at the function definition I've provided, it is incomplete.
# 2. Write in the command to move the robot RIGHT under the "#<<<<<< replace this with your code >>>>>>"
# 3. Test your answer with the "play button". If it works your robot should move forward and you can move to the next cell.

# All custom fucntions start with "def" then the name of the function and two perentheses
def turn_right():
    # Print statement: tells us whats happening
    print("Waking up robot")
    rvr.wake()
    time.sleep(2) # Computer waits for 2 seconds as the robot wakes up
    
    # GEORGE's Solution:
    rvr.raw_motors(
        left_mode=RawMotorModesEnum.foward.value,
        left_duty_cycle=75,  # Valid duty cycle range is 0-255
        right_mode=RawMotorModesEnum.reverse.value,
        right_duty_cycle=75  # Valid duty cycle range is 0-255
        )


# Execuate the new custom function
turn_right()


#### ------> ACTIVITY A1.3: turn_right and turn_left functions <-----#####
# Complete the custom function, "turn_left" for our robot

##### INSTRUCTIONS: #####
# 1. Quickly look at the function definition I've provided, it is incomplete.
# 2. Write in the command to move the robot LEFT under the "#<<<<<< replace this with your code >>>>>>"
# 3. Test your answer with the "play button". If it works your robot should move forward and you can move to the next cell.

# All custom fucntions start with "def" then the name of the function and two perentheses
def turn_left():
    # Print statement: tells us whats happening
    print("Waking up robot")
    rvr.wake()
    time.sleep(2) # Computer waits for 2 seconds as the robot wakes up
    
    # GEORGE's Solution:
    rvr.raw_motors(
        left_mode=RawMotorModesEnum.reverse.value,
        left_duty_cycle=50,  # Valid duty cycle range is 0-255
        right_mode=RawMotorModesEnum.forward.value,
        right_duty_cycle=50  # Valid duty cycle range is 0-255
        )

# Execuate the new custom function
turn_left()

# %% [markdown]
# #### ------> SOLUTION - Activity A1.4: Complete the Square <-----#####

# %%
#### ------> ACTIVITY A1.4: Complete the Square <-----#####
# Use your custom functions to make your robot draw a square on the ground. Just like turtle!

##### INSTRUCTIONS: #####
# 1. Use the functions you've created to write a sequence of moves for your robot, this sequence should direct the robot draw a square.
# 2. Test, test, test. When you're successful get a staff member to see your robot do a square.

# GEORGE's Solution:
move_forward()
turn_right()
move_forward()
turn_right()
move_forward()
turn_right()
move_forward()
turn_right()

# %% [markdown]
# ### Wrapping Up
# Before you move on to the next notebook, run the cell below to release the robot's connection. This keeps things clean for whichever notebook you open next.

# %%
#### ------> RUN THIS CELL WHEN YOU'RE DONE WITH THIS NOTEBOOK <-----#####
close_if_exists()
print("Robot connection closed. Safe to move on to the next notebook!")
