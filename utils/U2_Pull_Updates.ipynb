# %% [markdown]
# # U2 - Utilities: Pull Updates from Github
# Author: George Gorospe, george.gorospe@nmaia.net (updated 2/2/2026)
# **Repo: *robotics-training-institute-2026***
#
# ## In this utility notebook we use git, a tool for version control, to pull the latest updates for our racer's software.
# ### Version control is used within the NMAIA to send new software to each robot at each school and to help the students share their software with the NMAIA.

# %% [markdown]
# ## Updating the local branch or working copy:
# If our branch (the code on our robot) is behind the online repository (cloud), then we would like to update the branch with the content from the main software repository.
# The following commands retrieve the latest version of the software, updating our branch so that it is up to date.

# %%
# Get the latest software from the main software repo.
# !git fetch origin main
# !git reset --hard FETCH_HEAD

# %%
# Check git status one more time
# !git status

# %% [markdown]
# ## Updating the local backup:
#
# Also updating the backup directory. This backup directory holds untouched notebooks that can be copied if the working notebooks become broken.

# %%
# Step 1: Check if the backup folder exists.

import os
backup_directory = "/home/student/.backup"
backupExists = os.path.exists(backup_directory)

if not backupExists: # No backup found
    # Create the backup directory
    print("Creating backup directory")
    os.mkdir(backup_directory)

    # Change directory to backup directory
    os.chdir(backup_directory)

    # Clone github repo for AI Racer
    # !gh repo clone GGorospe/robotics-training-institute-2026

elif backupExists: # Update backup
    print("Found backup directory")
    # Change directory to backup directory
    os.chdir(backup_directory+"/robotics-training-institute-2026")

    # Get the latest software from the main software repo.
    print("Updating backup files")
    # !git fetch origin main
    # !git reset --hard FETCH_HEAD
